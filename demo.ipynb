# %%
import pandas as pd

data = pd.read_csv('clean_data.csv')

# %%
data
# Out:
#         Unnamed: 0  Store  Dept        Date  Weekly_Sales  IsHoliday  \
# 0                0      1     1  2010-02-05      24924.50      False
# 1                1      1     2  2010-02-05      50605.27      False
# 2                2      1     3  2010-02-05      13740.12      False
# 3                3      1     4  2010-02-05      39954.04      False
# 4                4      1     5  2010-02-05      32229.38      False
# ...            ...    ...   ...         ...           ...        ...
# 420207      421565     45    93  2012-10-26       2487.80      False
# 420208      421566     45    94  2012-10-26       5203.31      False
# 420209      421567     45    95  2012-10-26      56017.47      False
# 420210      421568     45    97  2012-10-26       6817.48      False
# 420211      421569     45    98  2012-10-26       1076.80      False
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  ...  Unemployment  \
# ...

# %%
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  2010-02-05        42.31       2.572       0.00       0.00
# 1           1  2010-02-05        42.31       2.572       0.00       0.00
# 2           1  2010-02-05        42.31       2.572       0.00       0.00
# 3           1  2010-02-05        42.31       2.572       0.00       0.00
# 4           1  2010-02-05        42.31       2.572       0.00       0.00
# ...       ...         ...          ...         ...        ...        ...
# 420207     45  2012-10-26        58.85       3.882    4018.91      58.08
# 420208     45  2012-10-26        58.85       3.882    4018.91      58.08
# 420209     45  2012-10-26        58.85       3.882    4018.91      58.08
# 420210     45  2012-10-26        58.85       3.882    4018.91      58.08
# 420211     45  2012-10-26        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...
